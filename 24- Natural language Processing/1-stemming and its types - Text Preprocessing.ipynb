# %% [markdown]
# ## Stemming
# Stemming is the process of reducing a word to its word stem that affixes to suffixes and prefixes or to the roots of words known as a lemma. Stemming is important in natural language understanding (NLU) and natural language processing (NLP).

# %%
# !pip install nltk

# %%
words=["eating","eats","eaten","writing","writes","programming","programs","history","finally","finalized"]

# %% [markdown]
# #### PorterStemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word + "---------->" + stemming.stem(word))

## from the below output we can see that the stemming of history word is not done properly.
# Out:
# eating---------->eat
# eats---------->eat
# eaten---------->eaten
# writing---------->write
# writes---------->write
# programming---------->program
# programs---------->program
# history---------->histori
# finally---------->final
# finalized---------->final

# %%
stemming.stem('congratulations') ## giving wrong words
# Out:
# 'congratul'

# %% [markdown]
# ### RegexpStemmer class
# NLTK has RegexpStemmer class with the help of which we can easily implement Regular Expression Stemmer algorithms. It basically takes a single regular expression and removes any prefix or suffix that matches the expression. Let us see an example

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eat'

# %%
reg_stemmer.stem('ingeating')
## does not removes the ing from the front ....to remove it also from back remove dollar from expression
# Out:
# 'ingeat'

# %%
## without dollar
reg_stemmer1 = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer1.stem('ingeating')
# Out:
# 'ingeat'

# %% [markdown]
# ### Snowball Stemmer
#  It is a stemming algorithm which is also known as the Porter2 stemming algorithm as it is a better version of the Porter Stemmer since some issues of it were fixed in this stemmer.

# %%
from nltk.stem import SnowballStemmer

# %%
snowballsstemmer = SnowballStemmer('english')

# %%
for word in words:
    print(word + "---------->" + snowballsstemmer.stem(word))

## so snowball stemmeing fixed most of the word which porter stemming does not fixed,
#  but there are some words which can not be also fixed by the snowball stemming.
# Out:
# eating---------->eat
# eats---------->eat
# eaten---------->eaten
# writing---------->write
# writes---------->write
# programming---------->program
# programs---------->program
# history---------->histori
# finally---------->final
# finalized---------->final

# %%
## by porter steemming
stemming.stem("fairly"),stemming.stem("sportingly") ## incorrect word stem
# Out:
# ('fairli', 'sportingli')

# %%
##by snowball stemming
snowballsstemmer.stem("fairly"),snowballsstemmer.stem("sportingly") ## correct stem word
# Out:
# ('fair', 'sport')

# %%
snowballsstemmer.stem('goes') ## does not fix properly - wrong word
# Out:
# 'goe'
