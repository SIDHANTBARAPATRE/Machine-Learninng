# %%
# !pip install gensim
# Out:
# ...
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#    ---------------------------------------- 0.3/24.4 MB ? eta -:--:--
#     --------------------------------------- 0.5/24.4 MB 475.9 kB/s eta 0:00:51
#    - -------------------------------------- 0.8/24.4 MB 584.2 kB/s eta 0:00:41
#    - -------------------------------------- 0.8/24.4 MB 584.2 kB/s eta 0:00:41
#    - -------------------------------------- 1.0/24.4 MB 641.2 kB/s eta 0:00:37
#    - -------------------------------------- 1.0/24.4 MB 641.2 kB/s eta 0:00:37
#    -- ------------------------------------- 1.3/24.4 MB 661.0 kB/s eta 0:00:35
#    -- ------------------------------------- 1.6/24.4 MB 706.8 kB/s eta 0:00:33
# ...

# %%
import gensim

# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
## model is very large it will take time to install it is of 2 gb...it already executed the cell then dont run it.
import gensim.downloader as api

wv = api.load('word2vec-google-news-300')

vec_king = wv['king']
# Out:
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king.shape
# Out:
# (300,)

# %%
## takes toime to execute.
wv.most_similar('cricket')
# Out:
# [('cricketing', 0.8372225761413574),
#  ('cricketers', 0.8165745735168457),
#  ('Test_cricket', 0.8094819784164429),
#  ('Twenty##_cricket', 0.8068487644195557),
#  ('Twenty##', 0.7624265551567078),
#  ('Cricket', 0.75413978099823),
#  ('cricketer', 0.7372579574584961),
#  ('twenty##', 0.7316356897354126),
#  ('T##_cricket', 0.7304614186286926),
#  ('West_Indies_cricket', 0.6987985372543335)]

# %%
wv.similarity("hockey", "cricket")
# Out:
# np.float32(0.4564136)

# %%
vec = wv['king']-wv['man']+wv['women']
